# %%
#importing the library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#load the data
df=pd.read_csv('F:\ML classes\Assignment\car data.csv')

# %%
#data exploration
df.head( )
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
#describe
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.shape
# Out:
# (301, 9)

# %%
df['Car_Name']
# Out:
# 0         ritz
# 1          sx4
# 2         ciaz
# 3      wagon r
# 4        swift
#         ...
# 296       city
# 297       brio
# 298       city
# 299       city
# 300       brio
# Name: Car_Name, Length: 301, dtype: object

# %%
df['Car_Name'].value_counts()
# Out:
# city                        26
# corolla altis               16
# verna                       14
# fortuner                    11
# brio                        10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: Car_Name, Length: 98, dtype: int64

# %%
df['Seller_Type'].value_counts()
# Out:
# Dealer        195
# Individual    106
# Name: Seller_Type, dtype: int64

# %%
df['Transmission'].value_counts()
# Out:
# Manual       261
# Automatic     40
# Name: Transmission, dtype: int64

# %%
#min and max value
np.max(df)
# Out:
# Car_Name              xcent
# Year                   2018
# Selling_Price          35.0
# Present_Price          92.6
# Kms_Driven           500000
# Fuel_Type            Petrol
# Seller_Type      Individual
# Transmission         Manual
# Owner                     3
# dtype: object

# %%
np.max(df,axis=1)
# Out:
# C:\Users\HAPPY BIRTHDAY\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:85: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return reduction(axis=axis, out=out, **passkwargs)
# 0      27000.0
# 1      43000.0
# 2       6900.0
# 3       5200.0
# 4      42450.0
#         ...
# 296    33988.0
# 297    60000.0
# 298    87934.0
# 299     9000.0
# 300     5464.0
# Length: 301, dtype: float64

# %%
#create distribution plot
plt.figure(figsize=[11,5])
sns.distplot(df['Selling_Price'])
plt.title('price distribution_plot')
# Out:
# C:\Users\HAPPY BIRTHDAY\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'price distribution_plot')

# %%
plt.figure(figsize=[10,4])
sns.distplot(df['Year'])
plt.title('Year_of_manufacture_plot')
# Out:
# C:\Users\HAPPY BIRTHDAY\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Year_of_manufacture_plot')

# %%
plt.figure(figsize=[10,10])
sns.distplot(df['Kms_Driven'])
plt.title('kms_driven')
# Out:
# C:\Users\HAPPY BIRTHDAY\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'kms_driven')

# %%
plt.figure(figsize=[5,10])
sns.distplot(df['Kms_Driven'])
plt.title('kms_driven')
# Out:
# C:\Users\HAPPY BIRTHDAY\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'kms_driven')

# %%
plt.figure(figsize=[10,5])
sns.distplot(df['Kms_Driven'])
plt.title('kms_driven')
# Out:
# C:\Users\HAPPY BIRTHDAY\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'kms_driven')

# %%
#visualization
#scattered plot
plt.scatter(df.Kms_Driven,df.Seller_Type)

# %%
sns.scatter(df.Kms_Driven,df.Car_Name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\HAPPYB~1\AppData\Local\Temp/ipykernel_9172/959414109.py in <module>
# ----> 1 sns.scatter(df.Kms_Driven,df.Car_Name)
#
# AttributeError: module 'seaborn' has no attribute 'scatter'

# %%
plt.bar(df.Seller_Type,df.Kms_Driven)
# Out:
# <BarContainer object of 301 artists>

# %%
df.corr()
# Out:
#                    Year  Selling_Price  Present_Price  Kms_Driven     Owner
# Year           1.000000       0.236141      -0.047584   -0.524342 -0.182104
# Selling_Price  0.236141       1.000000       0.878983    0.029187 -0.088344
# Present_Price -0.047584       0.878983       1.000000    0.203647  0.008057
# Kms_Driven    -0.524342       0.029187       0.203647    1.000000  0.089216
# Owner         -0.182104      -0.088344       0.008057    0.089216  1.000000

# %%
#heatmap
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#create a count graph
sns.countplot(data=df,x='Fuel_Type')
# Out:
# <AxesSubplot:xlabel='Fuel_Type', ylabel='count'>

# %%
#labelling the graph
sns.countplot(data=df,x='Fuel_Type')
plt.title('Number of Cars grouped by fuel type')
plt.ylabel('Number of Cars')
plt.xlabel('Fuel Types')
# Out:
# Text(0.5, 0, 'Fuel Types')

# %%
sns.boxplot(x="Owner", y="Kms_Driven", data=df)
# Out:
# <AxesSubplot:xlabel='Owner', ylabel='Kms_Driven'>

# %%
sns.boxplot(x='Seller_Type',y='Kms_Driven',data=df)
# Out:
# <AxesSubplot:xlabel='Seller_Type', ylabel='Kms_Driven'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='Seller_Type',hue='Transmission',data=df)
# Out:
# <AxesSubplot:xlabel='Seller_Type', ylabel='count'>

# %%
sns.catplot(y='Transmission', hue='Year', kind='count',
            data=df)

# %%
fig, (axis1,axis2) = plt.subplots(1, 2, figsize = (20,5))
sns.countplot(x='Seller_Type', data=df, ax=axis1)
sns.barplot(x='Seller_Type', y='Selling_Price',data=df, ax=axis2 )
# Out:
# <AxesSubplot:xlabel='Seller_Type', ylabel='Selling_Price'>

# %%
fig, (axis1,axis2) = plt.subplots(1, 2, figsize = (20,5))
sns.countplot(x='Owner', data=df, ax=axis1)
sns.barplot(x='Owner', y='Selling_Price',data=df, ax=axis2 )
# Out:
# <AxesSubplot:xlabel='Owner', ylabel='Selling_Price'>

# %%
fig, (axis1,axis2) = plt.subplots(1, 2, figsize = (20,5))
sns.countplot(x='Selling_Price', data=df, ax=axis1)
sns.barplot(x='Selling_Price', y='Transmission',data=df, ax=axis2 )
# Out:
# <AxesSubplot:xlabel='Selling_Price', ylabel='Transmission'>

# %%
sns.scatterplot(data=df,x='Kms_Driven',y='Selling_Price')
# Out:
# <AxesSubplot:xlabel='Kms_Driven', ylabel='Selling_Price'>

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.Year.unique()
# Out:
# array([2014, 2013, 2017, 2011, 2018, 2015, 2016, 2009, 2010, 2012, 2003,
#        2008, 2006, 2005, 2004, 2007], dtype=int64)

# %%
df['Age'] = 2022-df['Year']

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Age
# 0      Dealer       Manual      0    8
# 1      Dealer       Manual      0    9
# 2      Dealer       Manual      0    5
# 3      Dealer       Manual      0   11
# 4      Dealer       Manual      0    8

# %%
sns.lineplot(data=df,x='Age',y='Selling_Price')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Selling_Price'>

# %%
#create diff line plot
sns.lineplot(data=df,x='Fuel_Type',y='Selling_Price')
# Out:
# <AxesSubplot:xlabel='Fuel_Type', ylabel='Selling_Price'>

# %%
sns.lineplot(data=df,x='Fuel_Type',y='Seller_Type')
# Out:
# <AxesSubplot:xlabel='Fuel_Type', ylabel='Seller_Type'>

# %%
sns.lineplot(data=df,x='Present_Price',y='Selling_Price')
# Out:
# <AxesSubplot:xlabel='Present_Price', ylabel='Selling_Price'>

# %%
#creating different bar plots
sns.barplot(data=df,x='Fuel_Type',y='Selling_Price')
# Out:
# <AxesSubplot:xlabel='Fuel_Type', ylabel='Selling_Price'>

# %%
sns.barplot(data=df,x='Present_Price',y='Selling_Price')
# Out:
# <AxesSubplot:xlabel='Present_Price', ylabel='Selling_Price'>

# %%
sns.barplot(data=df,x='Year',y='Kms_Driven')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Kms_Driven'>

# %%
sns.catplot(x='Fuel_Type', y='Kms_Driven',
                hue='Owner', col='Transmission',
                data=df, kind='box',
                height=7, aspect=.8);

# %%
#to check the Null values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.Car_Name.value_counts()
# Out:
# city                        26
# corolla altis               16
# verna                       14
# fortuner                    11
# brio                        10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: Car_Name, Length: 98, dtype: int64

# %%
df.Owner.unique()
# Out:
# array([0, 1, 3], dtype=int64)

# %%
import dtale as dt
dt.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://WINI:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import sweetviz as sv
my_report = sv.analyze(df)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
my_report.show_html()
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
analyze(source:Union[df,Tuple[df,str]],
        target_feat:str = None,
        feat_cfg: FeatureConfig = None,
        pairwise_analysis:str ='auto'):
# Out:
#   File "C:\Users\HAPPYB~1\AppData\Local\Temp/ipykernel_11344/1734986619.py", line 1
#     analyze(source:Union[df,Tuple[df,str]],
#                   ^
# SyntaxError: invalid syntax

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Age
# 0      Dealer       Manual      0    8
# 1      Dealer       Manual      0    9
# 2      Dealer       Manual      0    5
# 3      Dealer       Manual      0   11
# 4      Dealer       Manual      0    8

# %%
y=df.Selling_Price

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
#defining variable
c=['Car_Name','Year','Fuel_Type','Seller_Type','Transmission','Owner']

# %%
c
# Out:
# ['Car_Name', 'Year', 'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']

# %%
#converting strings into numbers
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
le.fit_transform(c)
# Out:
# array([0, 5, 1, 3, 4, 2], dtype=int64)

# %%
df.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
c
# Out:
# ['Car_Name', 'Year', 'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']

# %%
# Instantiate the encoders
encoders = {column: LabelEncoder() for column in c}

for column in c:
    df[column] = encoders[column].fit_transform(df[column])

# %%
df.head()
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0        90    11           3.35           5.59       27000          2
# 1        93    10           4.75           9.54       43000          1
# 2        68    14           7.25           9.85        6900          2
# 3        96     8           2.85           4.15        5200          2
# 4        92    11           4.60           6.87       42450          1
#
#    Seller_Type  Transmission  Owner
# 0            0             1      0
# 1            0             1      0
# 2            0             1      0
# 3            0             1      0
# 4            0             1      0

# %%
y=df.Selling_Price

# %%
x= df.drop(['Selling_Price'], axis=1)

# %%
#split the dataset into training and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=102)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#pridiction
ypridct=lr.predict(x_test)

# %%
lr.intercept_
# Out:
# 1.9965951830680293

# %%
lr.coef_
# Out:
# array([-5.48147723e-03,  4.23105334e-01,  4.38910480e-01, -5.20458996e-06,
#        -1.57488999e+00, -1.46662668e+00, -1.48455028e+00, -5.08500175e-01])

# %%
sns.scatterplot(x_test['Owner'], y_test,  color='gray')
plt.plot(x_test, ypridct, color='Blue', linewidth=2)
plt.show()

# %%
sns.regplot(x='Year', y=df['Selling_Price'], data=df);

# %%
sns.scatterplot(x_test['Kms_Driven'], y_test,  color='gray')
plt.plot(x_test, ypridct, color='Blue', linewidth=1)
plt.show()

# %%
sns.regplot(x='Kms_Driven', y=df['Selling_Price'], data=df);

# %%
sns.regplot(x='Seller_Type', y=df['Selling_Price'], data=df);

# %%
sns.regplot(x='Car_Name', y=df['Selling_Price'], data=df);

# %%
plt.scatter(x_test['Owner'], y_test,  color='gray')
plt.plot(x_test, ypridct, color='Blue', linewidth=2)
plt.show()
